# %% [markdown]
# ## 9.1 線性迴歸演算法

# %% [markdown]
# ##9.1.2 正規方程法線性迴歸

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
folder="/content/drive/MyDrive/資料科學自學聖經/ch09"

# %% [markdown]
# 評估正規方程式線性迴歸的性能

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import pandas as pd

hp=pd.read_csv('/content/drive/MyDrive/資料科學自學聖經/ch09/housePrice.csv')
hp

# %%
x = hp.iloc[:, 0:12]
y = hp.iloc[:, 12]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
std_x = StandardScaler()
x_train = std_x.fit_transform(x_train)
x_test = std_x.transform(x_test)
std_y = StandardScaler()
y_train = std_y.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test = std_y.transform(y_test.to_numpy().reshape(-1, 1))
lr = LinearRegression()
lr.fit(x_train, y_train)
print('權重值：{}'.format(lr.coef_))
print('偏置值：{}'.format(lr.intercept_))

# %% [markdown]
# 進行資料測試

# %%
y_predict = std_y.inverse_transform(lr.predict(x_test))
y_real = std_y.inverse_transform(y_test)
for i in range(50):
  print('預測值：{}，真實值：{}'.format(y_predict[i], y_real[i]))

# %% [markdown]
# 計算平方差

# %%
merror = mean_squared_error(y_real, y_predict)
print('平均方差：{}'.format(merror))

# %% [markdown]
# ## 9.1.3 梯度下降法線性迴歸

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import pandas as pd

hp = pd.read_csv('/content/drive/MyDrive/資料科學自學聖經/ch09/housePrice.csv')
x = hp.iloc[:, 0:12]
y = hp.iloc[:, 12]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
std_x = StandardScaler()
x_train = std_x.fit_transform(x_train)
x_test = std_x.transform(x_test)
std_y = StandardScaler()
y_train = std_y.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test = std_y.transform(y_test.to_numpy().reshape(-1, 1))
sgd = SGDRegressor()
sgd.fit(x_train, y_train)
print('權重值：{}'.format(sgd.coef_))
print('偏置值：{}'.format(sgd.intercept_))
y_predict = std_y.inverse_transform(sgd.predict(x_test).reshape(-1, 1))
y_real = std_y.inverse_transform(y_test)
for i in range(20):
  print('預測值：{}，真實值：{}'.format(y_predict[i], y_real[i]))
merror = mean_squared_error(y_real, y_predict)
print('平均方差：{}'.format(merror))

# %% [markdown]
# #9.2 邏輯迴歸應用：判斷是否罹癌

# %% [markdown]
# ## 9.2.3 邏輯回歸應用:判斷是否罹癌

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("/content/drive/MyDrive/資料科學自學聖經/ch09/breastCancer.csv")
df

# %%
x = df.iloc[:, 0:9]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))

# %% [markdown]
# ## 9.2.6 召回率應用：提高罹癌患者檢測率

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

df = pd.read_csv("/content/drive/MyDrive/資料科學自學聖經/ch09/breastCancer.csv")
x = df.iloc[:, 0:9]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=1)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
y_pre = estimator.predict(x_test)
#pred_proba = estimator.predict_proba(x_test)[:, 1]
#thres = 0.15
#y_pre = np.where(pred_proba > thres, 2, 1)
ret = classification_report(y_test, y_pre, labels=(1, 2),
                            target_names=("良性", "惡性"))
print(ret)

# %% [markdown]
# #9.3 SVM分類範例：稻米種類判斷

# %% [markdown]
# ##9.3.3 支持向量機分類範例:稻米種類判斷

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

df = pd.read_csv("/content/drive/MyDrive/資料科學自學聖經/ch09/rice.csv")
df

# %%
x = df.iloc[:, 0:7]
y = df.iloc[:, 7]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
#clf = SVC(kernel='poly', gamma='auto', C=1, degree=3)
clf = SVC(kernel='linear', gamma='scale', C=1, degree=3)
clf.fit(x_train,y_train)
score = clf.score(x_test, y_test)
print("準確率：{}".format(score))

# %% [markdown]
# ##9.3.4 SVC應用：人臉辨識

# %% [markdown]
# 讀取Scikit-Learn人臉資料集(下載於'lfw_home'資料夾)

# %%
from sklearn.model_selection import \
    train_test_split
from sklearn.datasets import \
    fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.svm import SVC
lfw_people = fetch_lfw_people(data_home='.',
                    min_faces_per_person=70)
print(lfw_people.images.shape)

# %% [markdown]
# 取的特徵值與目標值

# %%
x = lfw_people.data
print('特徵維度:{}'.format(x.shape))
y = lfw_people.target
names = lfw_people.target_names
print('人臉姓名：')
print(lfw_people.target_names)

# %% [markdown]
# 進行訓練與預測

# %%
# %%time
#會計算程式執行時間,做為後面執行PCA後的時間比較
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=1)#random_state=1的意義為:每次進行訓練的基礎種子值都相同
clf = SVC(kernel='rbf', C=100, gamma='auto')
clf = clf.fit(x_train, y_train)
predict = clf.predict(x_test)
score = clf.score(x_test, y_test)
print("準確率：{}".format(score))
for i in range(20):
  print('預測值：{}，真實值：{}'.format(names[predict[i]],
                               names[y_test[i]]))

# %% [markdown]
# 使用PCA方法降低維度

# %%
# %%time
#會計算程式執行時間,做為後面執行PCA後的時間比較
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=1) #random_state=1 使資料分割固定
pca =PCA(svd_solver='randomized', n_components=100, whiten=True)
pca.fit(x, y)
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)
clf = SVC(kernel='rbf', C=100, gamma='auto')
clf = clf.fit(x_train_pca, y_train)
predict = clf.predict(x_test_pca)
score = clf.score(x_test_pca, y_test)
print("準確率：{}".format(score))
for i in range(20):
  print('預測值：{}，真實值：{}'.format(names[predict[i]],
                               names[y_test[i]]))

# %% [markdown]
# ## 9.3.5 SVM迴歸範例：廣告效益預測

# %% [markdown]
# 前4個欄位為:特徵值,第5個欄位為:目標值

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

df = pd.read_csv("/content/drive/MyDrive/資料科學自學聖經/ch09/advSale.csv")
df

# %% [markdown]
# 第四個欄位:網紅廣告為文字欄位,須以字典(dict)將文字轉換成1-4的數值資料

# %%
dict1 = {'大於百萬':1, '十萬到百萬':2, '一萬到十萬':3, '小於一萬':4}
df['網紅廣告'].replace(dict1, inplace=True)
df

# %% [markdown]
# 進行訓練資料標準化後,再進行支持向量機迴歸訓練

# %%
x = df.iloc[:, 0:4]
y = df.iloc[:, 4]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
std_x = StandardScaler()
x_train = std_x.fit_transform(x_train)
x_test = std_x.transform(x_test)
std_y = StandardScaler()
y_train = std_y.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test = std_y.transform(y_test.to_numpy().reshape(-1, 1))
clf = SVR(kernel='rbf', C=1, gamma='auto')
clf.fit(x_train, y_train)
y_predict = clf.predict(x_test)
y_predict = std_y.inverse_transform(y_predict.reshape(-1, 1))
y_real = std_y.inverse_transform(y_test)
for i in range(900):
  print('預測值：{}，真實值：{}'.format(y_predict[i], y_real[i][0]))
merror = mean_squared_error(y_real, y_predict)
print('平均方差：{}'.format(merror))
