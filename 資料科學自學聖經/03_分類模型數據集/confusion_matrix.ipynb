# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder="/content/drive/MyDrive/資料科學自學聖經/ch09"

# %% [markdown]
# 載入混淆矩陣套件

# %%
from sklearn.metrics import confusion_matrix
y_true = [0, 0, 1, 1, 0, 1] #真實值
y_pred = [0, 1, 0, 0, 0, 1] #預測值
confusion_matrix(y_true, y_pred)
# Out:
# array([[2, 1],
#        [2, 1]])

# %% [markdown]
# 混淆矩陣相關指標

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
y_true = [0, 0, 1, 1, 0, 1] #真實值
y_pred = [0, 1, 0, 0, 0, 1] #預測值

# Accuracy
accuracy=accuracy_score(y_true,y_pred)

# Precision
precision=precision_score(y_true,y_pred)

# recall_score
recall=recall_score(y_true,y_pred)

# f1_score
f1_score=f1_score(y_true,y_pred)

print('準確率：{}，精準率：{},召回率：{},F1_Score:{}'.format(accuracy, precision,recall,f1_score))
# Out:
# 準確率：0.5，精準率：0.5,召回率：0.3333333333333333,F1_Score:0.4
