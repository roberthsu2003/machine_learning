# %% [markdown]
# # Matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder="/content/drive/MyDrive/資料科學自學聖經/ch04/"

# %% [markdown]
# ## 折線圖

# %%
import matplotlib.pyplot as plt

listx = [1,5,7,9,13,16]
listy = [15,50,80,40,70,50]
plt.plot(listx, listy)
plt.show()

# %%
import matplotlib.pyplot as plt

listx = [1,5,7,9,13,16]
listy = [15,50,80,40,70,50]
plt.plot(listx, listy, color="green", lw="2.0", ls="-.", label="label")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

listx = [1,5,7,9,13,16]
listy = [15,50,80,40,70,50]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")
plt.legend()
plt.title("Chart Title", fontsize=20)  # 圖表標題
plt.xlabel("X-Label", fontsize=14)    # x軸標題
plt.ylabel("Y-Label", fontsize=14)    # y軸標題
plt.show()

# %% [markdown]
# # New Section

# %%
import matplotlib.pyplot as plt

listx = [1,5,7,9,13,16]
listy = [15,50,80,40,70,50]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")
plt.legend()
plt.title("Chart Title", fontsize=20)  # 圖表標題
plt.xlabel("X-Label", fontsize=14)    # x軸標題
plt.ylabel("Y-Label", fontsize=14)    # y軸標題
plt.xlim(0, 20)    #設定x軸範圍
plt.ylim(0, 100)   #設定y軸範圍
plt.show()

# %%
import matplotlib.pyplot as plt

listx = [1,5,7,9,13,16]
listy = [15,50,80,40,70,50]
plt.plot(listx, listy, color="blue", lw="2.0", ls="--", label="label")
plt.legend()
plt.title("Chart Title", fontsize=20)  # 圖表標題
plt.xlabel("X-Label", fontsize=14)    # x軸標題
plt.ylabel("Y-Label", fontsize=14)    # y軸標題
plt.xlim(0, 20)    #設定x軸範圍
plt.ylim(0, 100)   #設定y軸範圍
plt.grid(color='red', linestyle=':', linewidth=1, alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

listx1 = [1,5,7,9,13,16]
listy1 = [15,50,80,40,70,50]
plt.plot(listx1, listy1, 'r-.s')
listx2 = [2,6,8,11,14,16]
listy2 = [10,40,30,50,80,60]
plt.plot(listx2, listy2, 'y-s')
plt.show()

# %%
import matplotlib.pyplot as plt

listx1 = [1,5,7,9,13,16]
listy1 = [15,50,80,40,70,50]
listx2 = [2,6,8,11,14,16]
listy2 = [10,40,30,50,80,60]
plt.plot(listx1, listy1, 'r-.s', listx2, listy2, 'y-s')
plt.show()

# %%
import matplotlib.pyplot as plt
listx = [1000,2000,3000,4000,5000]
listy = [15,50,80,70,50]
plt.plot(listx, listy)
plt.xticks(listx)
plt.tick_params(axis='both', labelsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2015,2016,2017,2018,2019]
city1 = [128,150,199,180,150]
plt.plot(year, city1, 'r-.s', lw=2, ms=10, label="Taipei")
city2 = [120,145,180,170,120]
plt.plot(year, city2, 'g--*', lw=2, ms=10, label="Taichung")
plt.legend()
plt.ylim(50, 250)
plt.xticks(year)
plt.title("Sales Report", fontsize=18)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Million", fontsize=12)
plt.grid(color='k', ls=':', lw=1, alpha=0.5)
plt.show()

# %%
# 下載翰字鑄造-台北黑體
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# --2023-11-14 11:49:54--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 172.217.0.78, 2607:f8b0:4025:810::200e
# Connecting to drive.google.com (drive.google.com)|172.217.0.78|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0cm3i1obai33stinjna3eo2290ooa3tk/1699962525000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=5df9300d-c0d2-43d2-9aa6-f873cf299215 [following]
# ...
# --2023-11-14 11:49:57--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0cm3i1obai33stinjna3eo2290ooa3tk/1699962525000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=5df9300d-c0d2-43d2-9aa6-f873cf299215
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 172.217.15.225, 2607:f8b0:4025:802::2001
# ...

# %%
# 下載Google-思源正黑體
# !wget --content-disposition https://fonts.google.com/download?family=Noto%20Sans%20TC
# !unzip 'Noto_Sans_TC.zip'  #解壓縮到主機目錄
# Out:
# --2023-11-14 11:50:08--  https://fonts.google.com/download?family=Noto%20Sans%20TC
# Resolving fonts.google.com (fonts.google.com)... 172.217.164.14, 2607:f8b0:4025:803::200e
# Connecting to fonts.google.com (fonts.google.com)|172.217.164.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘Noto_Sans_TC.zip’
#
# Noto_Sans_TC.zip        [   <=>              ]  43.44M  79.0MB/s    in 0.5s
#
# 2023-11-14 11:50:13 (79.0 MB/s) - ‘Noto_Sans_TC.zip’ saved [45554326]
#
# Archive:  Noto_Sans_TC.zip
#   inflating: OFL.txt
#   inflating: static/NotoSansTC-Thin.ttf
#   inflating: static/NotoSansTC-ExtraLight.ttf
#   inflating: static/NotoSansTC-Light.ttf
#   inflating: static/NotoSansTC-Regular.ttf
#   inflating: static/NotoSansTC-Medium.ttf
#   inflating: static/NotoSansTC-SemiBold.ttf
#   inflating: static/NotoSansTC-Bold.ttf
#   inflating: static/NotoSansTC-ExtraBold.ttf
#   inflating: static/NotoSansTC-Black.ttf
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
# 加入中文字型設定：翰字鑄造-台北黑體
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')

year = [2015,2016,2017,2018,2019]
city1 = [128,150,199,180,150]
plt.plot(year, city1, 'r-.s', lw=2, ms=10, label="台北")
city2 = [120,145,180,170,120]
plt.plot(year, city2, 'g--*', lw=2, ms=10, label="台中")
plt.legend()
plt.ylim(50, 250)
plt.xticks(year)
plt.title("銷售報表", fontsize=18)
plt.xlabel("年度", fontsize=12)
plt.ylabel("百萬", fontsize=12)
plt.grid(color='k', ls=':', lw=1, alpha=0.5)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
# 加入中文字型設定：Google-思源正黑體
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

year = [2015,2016,2017,2018,2019]
city1 = [128,150,199,180,150]
plt.plot(year, city1, 'r-.s', lw=2, ms=10, label="台北")
city2 = [120,145,180,170,120]
plt.plot(year, city2, 'g--*', lw=2, ms=10, label="台中")
plt.legend()
plt.ylim(50, 250)
plt.xticks(year)
plt.title("銷售報表", fontsize=18)
plt.xlabel("年度", fontsize=12)
plt.ylabel("百萬", fontsize=12)
plt.grid(color='k', ls=':', lw=1, alpha=0.5)
plt.show()

# %% [markdown]
# ## 長條圖與橫條圖

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

listx = ['c','c++','c#','java','python']
listy = [45,28,38,32,50]
plt.bar(listx, listy, width=0.5, color=['r','g','b'])
plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

listy = ['c','c++','c#','java','python']
listx = [45,28,38,32,50]
plt.barh(listy, listx, height=0.5, color=['r','g','b'])
plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

listx = ['c','c++','c#','java','python']
listy1 = [25,20,20,16,28]
listy2 = [20,8,18,16,22]
plt.bar(listx, listy1, width=0.5, label='男')
plt.bar(listx, listy2, width=0.5, bottom=listy1, label='女')
plt.legend()
plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

width = 0.25
listx = ['c','c++','c#','java','python']
listx1 = [x - width/2 for x in range(len(listx))]
listx2 = [x + width/2 for x in range(len(listx))]
listy1 = [25,20,20,16,28]
listy2 = [20,8,18,16,22]
plt.bar(listx1, listy1, width, label='男')
plt.bar(listx2, listy2, width, label='女')
plt.xticks(range(len(listx)), labels=listx)
plt.legend()
plt.show()

# %% [markdown]
# ## 圓形圖

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Noto Sans TC')

sizes = [25, 30, 15, 10]
labels = ["北部", "西部", "南部", "東部"]
colors = ["red", "green", "blue", "yellow"]
explode = (0, 0, 0.2, 0)
plt.pie(sizes,
	explode = explode,
	labels = labels,
	colors = colors,
	labeldistance = 1.1,
	autopct = "%2.1f%%",
	pctdistance = 0.6,
	shadow = True,
	startangle = 90)
plt.show()

# %% [markdown]
# ## 直方圖

# %%
import matplotlib.pyplot as plt

data = [3,4,2,3,4,5,4,7,8,5,4,6,2,0,1,9,7,6,6,5,4]
plt.hist(data, bins=10)
plt.xlabel('Value')
plt.ylabel('Counts')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 散佈圖

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [1, 4, 9, 16, 7, 15, 17, 19]
sizes = [20, 200, 100, 50, 500, 1000, 60, 90]
colors = ["red","green","black","orange","purple","pink","cyan","magenta"]
plt.scatter(x, y, s=sizes, c=colors)
plt.show()

# %% [markdown]
# ## 線箱圖

# %%
import matplotlib.pyplot as plt

x=[3,4,5,6,8,9,10,10,11,12,13,15,15,17,18,20,22,23,25]
plt.boxplot(x)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[[3,4,5,6,8,9,10,10,11,12,13,15,15,17,18,20,22,23,25],
 [1,4,4,5,5,5,8,9,10,10,10,11,16,17,17,20,20,21,21,22]]
plt.boxplot(x)
plt.show()

# %%
import matplotlib.pyplot as plt

x1=[3,4,5,6,8,9,10,10,11,12,13,15,15,17,18,20,22,23,25]
x2=[[3,4,5,6,8,9,10,10,11,12,13,15,15,17,18,20,22,23,25],
  [1,4,4,5,5,5,8,9,10,10,10,11,16,17,17,20,20,21,21,22]]
plt.boxplot(x1)  #一維串列
plt.show()
plt.boxplot(x2)  #二維串列
plt.show()

# %%
import matplotlib.pyplot as plt
# 新增圖表區
plt.figure()
plt.plot([1,2,3])
# 新增圖表區並設定屬性
plt.figure(
    figsize=[10,4],
    facecolor="whitesmoke",
    edgecolor="r",
    linewidth=10,
    frameon=True)
plt.plot([1,2,3])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,8])
plt.subplot(2,1,1)
plt.title(label='Chart 1', fontsize=20)
plt.plot([1,2,3],'r:o')

plt.subplot(2,1,2)
plt.title(label='Chart 2', fontsize=20)
plt.plot([1,2,3],'g--o')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,8])
plt.subplot(1,2,1)
plt.title(label='Chart 1', fontsize=20)
plt.plot([1,2,3],'r:o')

plt.subplot(1,2,2)
plt.title(label='Chart 2', fontsize=20)
plt.plot([1,2,3],'g--o')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,8])
plt.subplot(2,2,1)
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')
plt.subplot(2,2,2)
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')
plt.subplot(2,2,3)
plt.title(label='Chart 3')
plt.plot([1,2,3],'b:o')
plt.subplot(2,2,4)
plt.title(label='Chart 4')
plt.plot([1,2,3],'y--o')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,4])
plt.axes([0,0,0.4,1])
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.axes([0.5,0,0.4,1])
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[8,4])
plt.axes([0,0,0.8,1])
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.axes([0.55,0.1,0.2,0.2])
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')
plt.show()

# %% [markdown]
# # Pandas

# %%
import pandas as pd
import matplotlib
from matplotlib.font_manager import fontManager
# 加入中文字型設定：翰字鑄造-台北黑體
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')

df = pd.DataFrame([[250,320,300,312,280],
							[280,300,280,290,310],
							[220,280,250,305,250]],
							index=['北部','中部','南部'],
							columns=[2015,2016,2017,2018,2019])

g1 = df.plot(kind='bar', title='長條圖', figsize=[10,5])
g2 = df.plot(kind='barh', title='橫條圖', figsize=[10,5])
g3 = df.plot(kind='bar', stacked=True, title='堆疊圖', figsize=[10,5])

# %%
import pandas as pd
import matplotlib
from matplotlib.font_manager import fontManager
# 加入中文字型設定：翰字鑄造-台北黑體
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')

df = pd.DataFrame([[250,320,300,312,280],
							[280,300,280,290,310],
							[220,280,250,305,250]],
							index=['北部','中部','南部'],
							columns=[2015,2016,2017,2018,2019])

g1 = df.iloc[0].plot(kind='line', legend=True,
							  xticks=range(2015,2020),
							  title='公司分區年度銷售表',
							  figsize=[10,5])
g1 = df.iloc[1].plot(kind='line',
							  legend=True,
							  xticks=range(2015,2020))
g1 = df.iloc[2].plot(kind='line',
									  legend=True,
									  xticks=range(2015,2020))

# %%
import pandas as pd
import matplotlib
from matplotlib.font_manager import fontManager
# 加入中文字型設定：翰字鑄造-台北黑體
fontManager.addfont('/content/NotoSansTC-VariableFont_wght.ttf')
matplotlib.rc('font', family='Taipei Sans TC Beta')

df = pd.DataFrame([[250,320,300,312,280],
                   [280,300,280,290,310],
                   [220,280,250,305,250]],
                  index=['北部','中部','南部'],
                  columns=[2015,2016,2017,2018,2019])
df.plot(kind='pie', subplots=True, figsize=[20,20])
# Out:
# array([<Axes: ylabel='2015'>, <Axes: ylabel='2016'>,
#        <Axes: ylabel='2017'>, <Axes: ylabel='2018'>,
#        <Axes: ylabel='2019'>], dtype=object)

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 長條圖與橫條圖

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
#計算不同天的小費總額
tips_total = tips.groupby("day", as_index=False).sum()
tips_total.head()
# Out:
# <ipython-input-43-54c719d7560a>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips_total = tips.groupby("day", as_index=False).sum()
#     day  total_bill     tip  size
# 0  Thur     1096.33  171.83   152
# 1   Fri      325.88   51.96    40
# 2   Sat     1778.40  260.40   219
# 3   Sun     1627.16  247.39   216

# %%
sns.barplot(data=tips_total, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips_total, x='tip', y='day')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## 折線圖

# %%
import seaborn as sns
sns.set_theme()
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
filghts1960 = flights[flights['year'] == 1960]
sns.lineplot(data=filghts1960, x='month', y='passengers')

# %% [markdown]
# ## 直方圖

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=tips, x='total_bill')

# %%
sns.displot(data=tips, x='total_bill', hue='time')

# %%
# 堆疊圖
sns.displot(data=tips, x='total_bill', hue='time', multiple="stack")

# %%
# 分置圖
sns.displot(data=tips, x='total_bill', hue='time', multiple="dodge")

# %%
sns.displot(data=tips, x='total_bill', col="time")

# %% [markdown]
# ## 散佈圖

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", style="sex")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", style="sex")

# %% [markdown]
# ## 線箱圖

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
sns.boxplot(data=tips["total_bill"])
# Out:
# <Axes: >

# %%
sns.boxplot(data=tips, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns
sns.set_theme()
tips = sns.load_dataset("tips")
tips.columns = ['消費金額','小費','性別','是否抽菸','星期幾','用餐時間','餐會規模']
tips.head()
# Out:
#     消費金額    小費      性別 是否抽菸  星期幾    用餐時間  餐會規模
# 0  16.99  1.01  Female   No  Sun  Dinner     2
# 1  10.34  1.66    Male   No  Sun  Dinner     3
# 2  21.01  3.50    Male   No  Sun  Dinner     3
# 3  23.68  3.31    Male   No  Sun  Dinner     2
# 4  24.59  3.61  Female   No  Sun  Dinner     4

# %%
sns.displot(data=tips, x='消費金額')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 28040 (\N{CJK UNIFIED IDEOGRAPH-6D88}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 36027 (\N{CJK UNIFIED IDEOGRAPH-8CBB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 38989 (\N{CJK UNIFIED IDEOGRAPH-984D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 28040 (\N{CJK UNIFIED IDEOGRAPH-6D88}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
# 下載Google-思源正黑體
# !wget --content-disposition https://fonts.google.com/download?family=Noto%20Sans%20TC
# !unzip 'Noto_Sans_TC.zip'  #解壓縮到主機目錄
# Out:
# --2023-11-21 11:27:04--  https://fonts.google.com/download?family=Noto%20Sans%20TC
# Resolving fonts.google.com (fonts.google.com)... 74.125.199.100, 74.125.199.102, 74.125.199.139, ...
# Connecting to fonts.google.com (fonts.google.com)|74.125.199.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘Noto_Sans_TC.zip’
#
# Noto_Sans_TC.zip        [    <=>             ]  43.44M  58.1MB/s    in 0.7s
#
# 2023-11-21 11:27:11 (58.1 MB/s) - ‘Noto_Sans_TC.zip’ saved [45554326]
#
# Archive:  Noto_Sans_TC.zip
#   inflating: OFL.txt
#   inflating: static/NotoSansTC-Thin.ttf
#   inflating: static/NotoSansTC-ExtraLight.ttf
#   inflating: static/NotoSansTC-Light.ttf
#   inflating: static/NotoSansTC-Regular.ttf
#   inflating: static/NotoSansTC-Medium.ttf
#   inflating: static/NotoSansTC-SemiBold.ttf
#   inflating: static/NotoSansTC-Bold.ttf
#   inflating: static/NotoSansTC-ExtraBold.ttf
# ...

# %%
# 修正Seaborn中文顯示問題
import matplotlib
from matplotlib.font_manager import fontManager
fontManager.addfont('NotoSansTC-Regular.otf')
matplotlib.rc('font', family='Noto Sans TC')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-0e96d9e98562> in <cell line: 4>()
#       2 import matplotlib
#       3 from matplotlib.font_manager import fontManager
# ----> 4 fontManager.addfont('NotoSansTC-Regular.otf')
#       5 matplotlib.rc('font', family='Noto Sans TC')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/font_manager.py in addfont(self, path)
#    1041             self.afmlist.append(prop)
#    1042         else:
# -> 1043             font = ft2font.FT2Font(path)
#    1044             prop = ttfFontProperty(font)
#    1045             self.ttflist.append(prop)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NotoSansTC-Regular.otf'

# %%
sns.displot(data=tips, x='消費金額')
