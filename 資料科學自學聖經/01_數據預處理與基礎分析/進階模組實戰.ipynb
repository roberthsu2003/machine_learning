# %% [markdown]
# #網路爬蟲資料收集

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder="/content/drive/MyDrive/資料科學自學聖經/ch03B"

# %% [markdown]
# ##新聞爬取模組

# %% [markdown]
# ###scraparazzie：Google News新聞爬取

# %%
# 安裝
# !pip install scraparazzie

# %%
# 使用模組
from scraparazzie import scraparazzie
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# 建立新聞物件
client=scraparazzie.NewsClient(language='chinese traditional',
                               location='Taiwan',
                               topic='Business',
                               max_results=10)
client.print_news() # 顯示資料
# Out:
# AI起飛外資喊買緯創、廣達不手軟
# 工商時報
# https://news.google.com/rss/articles/CBMiMmh0dHBzOi8vd3d3LmN0ZWUuY29tLnR3L25ld3MvMjAyMzExMTI3MDA2NTQtNDMwMjAx0gEA?oc=5
# Sun, 12 Nov 2023 13:53:00 GMT
# ------------------------------------------------------------
# 數位存款帳戶達1877萬戶進入「飽和期」 成年人幾乎都開了
# 聯合新聞網
# https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzcyMzkvNzU2OTA1M9IBK2h0dHBzOi8vdWRuLmNvbS9uZXdzL2FtcC9zdG9yeS83MjM5Lzc1NjkwNTM?oc=5
# Sun, 12 Nov 2023 11:56:47 GMT
# ------------------------------------------------------------
# 每年都號稱破紀錄 今年雙11為何靜悄悄？中國博主說出了實話
# 三立新聞網 Setn.com
# https://news.google.com/rss/articles/CBMiLWh0dHBzOi8vd3d3LnNldG4uY29tL05ld3MuYXNweD9OZXdzSUQ9MTM4MjA4NtIBMmh0dHBzOi8vd3d3LnNldG4uY29tL20vYW1wbmV3cy5hc3B4P05ld3NJRD0xMzgyMDg2?oc=5
# Sun, 12 Nov 2023 11:04:00 GMT
# ------------------------------------------------------------
# 中國雙11狂歡不再?淘天.京東遲未公布交易總額小米.華為新機賣爆!iPhone銷量砍價換來?｜非凡財經新聞｜20231112
# USTV 非凡電視
# ...

# %%
# 建立新聞物件
client=scraparazzie.NewsClient(language='english',
                location='United States',
                topic='Business',
                max_results=10)
client.print_news() # 顯示資料
# Out:
# Asia markets mostly higher; China prices shrink faster than expected
# CNBC
# https://news.google.?oc=5
# Thu, 09 Nov 2023 07:56:00 GMT
# ------------------------------------------------------------
# Sony reports 29% drop in operating profit as weakness in chip business hits home
# CNBC
# https://news.google.?oc=5
# Thu, 09 Nov 2023 07:07:14 GMT
# ...

# %% [markdown]
# ####參數查詢

# %%
# 參數查詢
# client.languages
# client.locations
# client.topics
# client.get_config()
# client.languages
client.locations
# Out:
# ['Australia',
#  'Botswana',
#  'Canada ',
#  'Ethiopia',
#  'Ghana',
#  'India ',
#  'Indonesia',
#  'Ireland',
#  'Israel ',
#  'Kenya',
#  'Latvia',
#  'Malaysia',
#  'Namibia',
#  'New Zealand',
#  'Nigeria',
#  'Pakistan',
#  'Philippines',
#  'Singapore',
#  'South Africa',
#  'Tanzania',
#  'Uganda',
#  'United Kingdom',
#  'United States',
#  'Zimbabwe',
#  'Czech Republic',
#  'Germany',
#  'Austria',
#  'Switzerland',
#  'Argentina',
#  'Chile',
#  'Colombia',
#  'Cuba',
#  'Mexico',
#  'Peru',
#  'Venezuela',
#  'Belgium ',
#  'France',
#  'Morocco',
#  'Senegal',
#  'Italy',
#  'Lithuania',
#  'Hungary',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Brazil',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Vietnam',
#  'Turkey',
#  'Greece',
#  'Bulgaria',
#  'Russia',
#  'Ukraine ',
#  'Serbia',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'Lebanon',
#  'Egypt',
#  'Bangladesh',
#  'Thailand',
#  'China',
#  'Taiwan',
#  'Hong Kong',
# ...

# %%
client.get_config()
# Out:
# {'location': 'Taiwan',
#  'language': 'chinese traditional',
#  'topic': 'Business',
#  'query': None}

# %% [markdown]
# #### 取得新聞資料

# %%
# 串列資料=新聞物件.export_news()
items=client.export_news()
print(items)
# Out:
# [{'title': 'AI起飛外資喊買緯創、廣達不手軟', 'source': '工商時報', 'link': 'https://news.google.com/rss/articles/CBMiMmh0dHBzOi8vd3d3LmN0ZWUuY29tLnR3L25ld3MvMjAyMzExMTI3MDA2NTQtNDMwMjAx0gEA?oc=5', 'publish_date': 'Sun, 12 Nov 2023 13:53:00 GMT'}, {'title': '數位存款帳戶達1877萬戶進入「飽和期」 成年人幾乎都開了', 'source': '聯合新聞網', 'link': 'https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzcyMzkvNzU2OTA1M9IBK2h0dHBzOi8vdWRuLmNvbS9uZXdzL2FtcC9zdG9yeS83MjM5Lzc1NjkwNTM?oc=5', 'publish_date': 'Sun, 12 Nov 2023 11:56:47 GMT'}, {'title': '每年都號稱破紀錄 今年雙11為何靜悄悄？中國博主說出了實話', 'source': '三立新聞網 Setn.com', 'link': 'https://news.google.com/rss/articles/CBMiLWh0dHBzOi8vd3d3LnNldG4uY29tL05ld3MuYXNweD9OZXdzSUQ9MTM4MjA4NtIBMmh0dHBzOi8vd3d3LnNldG4uY29tL20vYW1wbmV3cy5hc3B4P05ld3NJRD0xMzgyMDg2?oc=5', 'publish_date': 'Sun, 12 Nov 2023 11:04:00 GMT'}, {'title': '中國雙11狂歡不再?淘天.京東遲未公布交易總額小米.華為新機賣爆!iPhone銷量砍價換來?｜非凡財經新聞｜20231112', 'source': 'USTV 非凡電視', 'link': 'https://news.google.com/rss/articles/CCAiCzhUS0xHQjBXaTRRmAEB?oc=
# ...

# %%
items[9]
# Out:
# {'title': '最可愛的純電露營車，福斯ID.Buzz 台灣首度亮相',
#  'source': 'TechNews 科技新報 ',
#  'link': 'https://news.google.com/rss/articles/CBMiOWh0dHBzOi8vdGVjaG5ld3MudHcvMjAyMy8xMS8xMC92b2xrc3dhZ2VuLWlkLWJ1enotdGFpd2FuL9IBAA?oc=5',
#  'publish_date': 'Sat, 11 Nov 2023 05:04:06 GMT'}

# %%
items[5]['title']
# Out:
# '鴻海低軌衛星「珍珠號」完成部署 成功回傳訊號'

# %% [markdown]
# #### 範例：取得5則台灣股市新聞資料並顯示

# %%
# 範例：取得5則台灣股市新聞資料並顯示
from scraparazzie import scraparazzie
client = scraparazzie.NewsClient(language = 'chinese traditional', location = 'Taiwan', query = '股市', max_results = 5)
items = client.export_news()
print(len(items))
for i,item in enumerate(items):
  # print(item)
  print('第 ' + str(i+1) + ' 則新聞：')
  print('新聞標題：' + item['title'])
  print('新聞機構：' + item['source'])
  print('新聞連結：' + item['link'])
  print('新聞時間：' + item['publish_date'])


# for i, item in enumerate(items):
#   print('第 ' + str(i+1) + ' 則新聞：')
#   print('新聞標題：' + item['title'])
#   print('新聞機構：' + item['source'])
#   print('新聞連結：' + item['link'])
#   print('新聞時間：' + item['publish_date'])
#   print('========================================================================================')
# Out:
# 5
# 第 1 則新聞：
# 新聞標題：《台北股市》力旺明年業績續好、新日興急單抱到Q4 營運強
# 新聞機構：Yahoo奇摩股市
# 新聞連結：https://news.google.com/rss/articles/CBMi-...?oc=5
# 新聞時間：Sun, 12 Nov 2023 09:00:00 GMT
# 第 2 則新聞：
# 新聞標題：《台北股市》六利多加持台股年底行情有撐
# 新聞機構：Yahoo奇摩股市
# 新聞連結：https://news.google.?oc=5
# 新聞時間：Sun, 12 Nov 2023 08:30:37 GMT
# 第 3 則新聞：
# 新聞標題：《台北股市》雷笛克10月營收雙增、寒舍技術面轉強 有看頭
# 新聞機構：Yahoo奇摩股市
# 新聞連結：https://news.google.com/rss/articles/CBMi-...?oc=5
# 新聞時間：Sun, 12 Nov 2023 08:13:39 GMT
# 第 4 則新聞：
# 新聞標題：《台北股市》雙利多可期 台股補量攻萬七
# 新聞機構：Yahoo奇摩股市
# 新聞連結：https://news.google....?oc=5
# 新聞時間：Sun, 12 Nov 2023 05:32:14 GMT
# 第 5 則新聞：
# 新聞標題：《台北股市》台股後市怎麼走？法人這樣看
# 新聞機構：Yahoo奇摩股市
# 新聞連結：https://news.google....?oc=5
# 新聞時間：Sun, 12 Nov 2023 02:20:57 GMT

# %% [markdown]
# #### 練習：取得5則台灣口罩新聞資料並顯示

# %%
# 練習：顯示取得5則台灣口罩新聞資料並顯示
from scraparazzie import scraparazzie
client = scraparazzie.NewsClient(language = 'chinese traditional', location = 'Taiwan', query = '日本旅遊', max_results = 5)
items = client.export_news()
#print(len(items))
print(items)
# Out:
# [{'title': '日本旅遊｜東京新景點！ 銀座沉浸式金魚藝術館 盤點5大必影打卡位 金魚瀑布/寶石魚缸', 'source': '雅虎香港新聞', 'link': 'https://news.google....?oc=5', 'publish_date': 'Sat, 11 Nov 2023 05:14:32 GMT'}, {'title': '日本旅遊｜星野溫泉品牌「界」首次進駐宮城縣！2024年春季開業 坐擁溫泉勝地「秋保溫泉」四季靚景、一泊二食人均$1,XXX起', 'source': '雅虎香港新聞', 'link': 'https://news.google....?oc=5', 'publish_date': 'Thu, 09 Nov 2023 01:17:17 GMT'}, {'title': '日本旅遊｜萬豪第5間豪華酒店選址奈良公園！建築大師隈研吾作品、43間自然木風房嘆庭園景色', 'source': '雅虎香港新聞', 'link': 'https://news.google....?oc=5', 'publish_date': 'Wed, 08 Nov 2023 22:30:55 GMT'}, {'title': '「為什麼日本人沒那麼愛來台灣觀光了？」一位旅台10年日本人的 ...', 'source': '天下雜誌', 'link': 'https://news.google.com/rss/articles/CBMiJWh0dHBzOi8vd3d3LmN3LmNvbS50dy9hcnRpY2xlLzUxMjc5NTTSAQA?oc=5', 'publish_date': 'Mon, 06 Nov 2023 16:00:00 GMT'}, {'title': '日本環球影城買一送一 易遊網線上旅展46折起、150間日本飯店獨家5折', 'source': '聯合新聞網', 'link': 'https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vdWRuLmNvbS9uZXdzL3N0b3J5LzcyNzAvNzU0Njk4NdIBK2h0dHBzOi8vdWRuLmNvbS9uZXdzL2FtcC9zdG9yeS83MjcwLzc1NDY5ODU?oc=5', 'publis
# ...

# %% [markdown]
# ###Newspaper3k：爬取全球新聞

# %%
# 安裝
# !pip install newspaper3k
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 6.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 22.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=2d6d8a12b8f4b01fb01981525f497a74ecf5adfdb623eb355af5231c51070dbf
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3339 sha256=98f4d9e67b421fd8c1938c1c3f260560256fa887e6f59159d70e0ede1e0682a8
# ...

# %%
# 使用模組
import newspaper

# %%
# 參數查詢
# newspaper.popular_urls()
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   pt			  Portuguese
#   fi			  Finnish
#   hu			  Hungarian
#   sr			  Serbian
#   ko			  Korean
#   tr			  Turkish
#   vi			  Vietnamese
#   sv			  Swedish
#   uk			  Ukrainian
#   he			  Hebrew
#   ja			  Japanese
#   pl			  Polish
#   it			  Italian
#   be			  Belarusian
#   nl			  Dutch
#   sl			  Slovenian
#   es			  Spanish
#   ru			  Russian
#   fa			  Persian
#   sw			  Swahili
#   el			  Greek
#   no			  Norwegian
#   hr			  Croatian
#   da			  Danish
#   ar			  Arabic
#   mk			  Macedonian
#   bg			  Bulgarian
#   ro			  Romanian
#   hi			  Hindi
#   et			  Estonian
#   fr			  French
#   en			  English
#   nb			  Norwegian (Bokmål)
#   de			  German
#   zh			  Chinese
#   id			  Indonesian

# %%
# 建立新聞物件
paper = newspaper.build('https://cn.wsj.com/zh-hant', language='zh')
# print('新聞連結：')
print(paper.articles)
# Out:
# WARNING:newspaper.parsers:fromstring() returned an invalid string: ...
# WARNING:newspaper.source:Source https://cn.wsj.com/zh-hant parse error.
# CRITICAL:newspaper.extractors:Must extract urls from either html, text or doc!
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://cn.wsj.com/zh-hant
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://cn.wsj.com/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://cn.wsj.com/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://cn.wsj.com/feed
# ...

# %%
for article in paper.articles:
  print(article.url)
# Out:
# https://cn.wsj.com/zh-hans/news/world?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/china?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/markets?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/economy?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/business?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/technology?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/life-arts?mod=nav_top_section
# https://cn.wsj.com/zh-hans/news/opinion?mod=nav_top_section
# http://www.wsj.com/video/china?mod=nav_top_section
# https://www.wsj.com/video/china/2DD3E185-69F8-4B1A-A202-72B7B3B427B3.html?mod=error_page
# https://www.wsj.com/video/china/9B3FA5A0-9C70-4929-A42A-34D6854230B2.html?mod=error_page
# https://www.wsj.com/video/china/A7F9C1B1-5187-4149-97FD-2FEAB8826E78.html?mod=error_page
# https://www.wsj.com/video/china
# https://www.wsj.com/news/column/corrections?mod=wsjfooter
# https://cn.wsj.com/zh-hans/news/archive

# %% [markdown]
# #### Artccle 取得單一新聞

# %%
# Artccle 取得單一新聞
from newspaper import Article
# 自由時報
url = 'https://news.ltn.com.tw/news/life/breakingnews/3649202'
article=Article(url)
article.download()
print(article.html)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW" itemscope itemtype="https://schema.org/NewsArticle">
#     <head>
#         <script> var pvDomain = 'pv.ltn.com.tw'; </script>
# <script> var pvServer = 'pv.ltn.com.tw'; </script>
# <script>var interstitialSlot;</script>
# <script>var staticSlot = false;</script>
# <script src="https://cache.ltn.com.tw/js/c.js"></script>
#         <base href='https://news.ltn.com.tw/'>
#         <meta name="ltn:device" content="R" />
#         <title>普度祭拜募集物資助弱 台南仁德區保華宮中元送愛 - 生活 - 自由時報電子報</title>
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta property="og:site_name" name="application-name" content="自由時報電子報" />
# <meta name="author" itemprop="author" content="自由時報電子報" />
# <meta name="dcterms.rightsHolder" content="自由時報電子報" />
# <meta name="copyright" content="自由時報電子報" />
# ...

# %%
article.parse()
article.title
# Out:
# Building prefix dict from /usr/local/lib/python3.10/dist-packages/jieba/dict.txt ...
# DEBUG:jieba:Building prefix dict from /usr/local/lib/python3.10/dist-packages/jieba/dict.txt ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 3.208787202835083 seconds.
# DEBUG:jieba:Loading model cost 3.208787202835083 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# '普度祭拜募集物資助弱 台南仁德區保華宮中元送愛'

# %%
# parse() 解析
article.parse()
print('【新聞標題】')
print(article.title)
print('【新聞內容】]：')
print(article.text)
print('【新聞日期】')
print(article.publish_date)
# Out:
# 【新聞標題】
# 普度祭拜募集物資助弱 台南仁德區保華宮中元送愛
# 【新聞內容】]：
# 仁德區保華宮將中元普度結合愛心公益，捐助弱勢。（記者吳俊鋒攝）
#
# 2021/08/24 20:07
#
# 〔記者吳俊鋒／台南報導〕台南仁德區的保華宮，結合中元普度，與社會大眾聯手募集愛心供品，包含1800斤的白米，以及各式生活物資，祭拜後，今天一併發放給低收入戶，照顧弱勢，讓民間傳統習俗也兼具慈善公益的意義。
#
# 保華宮主委黃翠雲指出，農曆7月也是慈悲月，今年適逢防疫警戒，呼籲信眾以代購普品的方式，做好中元祭拜，並降低群聚風險，還號召活動之後捐助給有需要幫助的⼈，廟方抱持感恩的心，善盡社會責任，獲得熱烈迴響。
#
# 請繼續往下閱讀...
#
# 仁德區公所轄內列冊的低收入家庭有237戶，保華宮準備豐盛的供品，宴請四方好兄弟，並將募集的愛心米，連同麵食、罐頭、油品等物資一起捐助弱勢，今天在廟內發放。
#
# 該廟還提供了環保袋，將救濟物資裝好，讓低收入戶方便領取，市議員吳禹寰也到場協助發放，並呼籲社會各界，疫情期間，弱勢生活大不易，需要更多關懷。
#
# 仁德區保華宮將中元普度結合愛心公益，捐助弱勢。（記者吳俊鋒攝）
#
# 不用抽 不用搶 現在用APP看新聞 保證天天中獎 點我下載APP 按我看活動辦法
# 【新聞日期】
# 2021-08-24 20:07:54+08:00

# %% [markdown]
# #### 練習：取得蘋果日報新聞
# https://www.appledaily.com.tw/

# %%
# 練習：取得蘋果日報新聞
from newspaper import Article
url = 'https://tw.nextapple.com/'

# parse() 解析
article=Article(url)
article.download()
article.parse()
print('【新聞標題】')
print(article.title)
print('【新聞內容】]：')
print(article.text)
print('【新聞日期】')
print(article.publish_date)
# Out:
# 【新聞標題】
# 壹蘋新聞網
# 【新聞內容】]：
# 【記者施智齡／台北報導】台積電創辦人張忠謀今天獲頒「第一屆李國鼎獎」，總統蔡英文、前副總統蕭萬長及輝達創辦人黃仁勳等多名科技業大老均出席，現場冠蓋雲集。蔡英文入座前跟張忠謀熱情擁抱，她並在黃仁勳致詞後上台，笑指在黃仁勳後面講話「壓力實在很大、非常大」。蔡英文感謝張忠謀的付出，助台灣走向世界，也讓世界走進台灣，同時蔡英文也感謝已故的李國鼎帶領台灣走過關鍵年代，是台灣經濟奇蹟的領航者。
# 【新聞日期】
# None

# %% [markdown]
# ###technews-tw：台灣科技新聞爬取

# %%
# 安裝
# !pip install technews-tw
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.1 MB/s eta 0:00:00
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=28b01090f206233bcf647a5fe89036db6ef96619982fd09b3f32867b73c70ac6
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %% [markdown]
# ####取得 inside 當天發佈的新聞

# %%
# 使用模組
from technews import TechNews

# 取得 inside 當天發佈的新聞
# news = TechNews("business").get_today_news()
# news = TechNews("orange").get_today_news()
# news = TechNews("ithome").get_today_news()
news = TechNews("inside").get_today_news()
print(news)
# Out:
# {'timestamp': 1699518973.8889713, 'news_page_title': 'INSIDE', 'news_contents': {'9dc6f009de0a68ed0ac7870943f90261': {'link': 'https://www.inside.com.tw/article/33297-ktli-prize', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/4e27fb38-3241-4607-b350-e0c57f508518.jpg?w=400&h=209&fit=crop&auto=compress', 'title': '身兼李國鼎科技發展基金會董事長，王伯元表示希望透過李國鼎獎的設立，傳揚李國鼎的時代精神，帶給台灣產業界以更高層的合作大戰略。', 'date': '2023-11-09'}, '1e23cec799b2ac41995932a94a5f3592': {'link': 'https://www.inside.com.tw/article/33295-hollywood-actor-strike-ended', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/d778438a-ff55-4dd6-93d8-0c6393150a9f.jpg?w=400&h=209&fit=crop&auto=compress', 'title': '雙方在罷工期間的談判中，AI 的應用是核心議題之一，AMPTP 稱在使用演員的數位 AI 分身前會先取得演員同意；而 SAG 則反駁這造成演員僅需被支付一次薪水，其身分就可以被永久使用的問題。', 'date': '2023-11-09'}, 'b41b2efe930894076a8db5e37f040f93': {'link': 'https://www.inside.com.tw/article/33296-omegle-closed', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/1668440e-9381-40f2-814c-3e7a79d493f6.jp
# ...

# %% [markdown]
# ####取得N天內科技新聞

# %%
# 取得 3 天內科技新聞
# news3 = TechNews("business").get_news_by_page(3)
# news3 = TechNews("orange").get_news_by_page(3)
# news3 = TechNews("ithome").get_news_by_page(3)
news3 = TechNews("inside").get_news_by_page(3)
print(news3)
# Out:
# {'timestamp': 1699518981.7328186, 'news_page_title': 'INSIDE', 'news_contents': {'8a7cf074d17cf163d1c8ea6de2dd03ab': {'link': 'https://www.inside.com.tw/article/33300-anthropic-google-tpu', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/d9b69cd1-1d46-4456-ae44-5b6a46a5d08a.jpg?w=400&h=209&fit=crop&auto=compress', 'title': '另一家與 Anthropic 關係匪淺的公司則是 Amazon。Google Cloud CEO Thomas Kurian 指出，並不對於 Anthropic 與 AWS 的合作感到困擾，「大企業總是希望選擇多種雲端。」', 'date': '2023-11-09'}, '9dc6f009de0a68ed0ac7870943f90261': {'link': 'https://www.inside.com.tw/article/33297-ktli-prize', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/4e27fb38-3241-4607-b350-e0c57f508518.jpg?w=400&h=209&fit=crop&auto=compress', 'title': '身兼李國鼎科技發展基金會董事長，王伯元表示希望透過李國鼎獎的設立，傳揚李國鼎的時代精神，帶給台灣產業界以更高層的合作大戰略。', 'date': '2023-11-09'}, '97595b5b86770efcca14d68238fcca00': {'link': 'https://www.inside.com.tw/article/33256-pCloud', 'image': 'https://bucket-img.tnlmedia.com/cabinet/2023/11/4749ab2a-b015-4a4e-8e0f-441b6813a0e6.jp
# ...

# %% [markdown]
# ####範例：逐筆顯示新聞資料

# %%
# 逐筆顯示新聞資料
news3 = TechNews("business").get_news_by_page(3)
content = news3['news_contents']
for key in content:
    mononews = content[key]
    print('新聞標題：', mononews['title'])
    print('新聞連結：', mononews['link'])
    print('發布日期：', mononews['date'])
    print('========================================================================')
# Out:
# 新聞標題： 李開復「零一萬物」8個月躋身AI獨角獸、超越Meta！為何「靈活」躲過美國禁令？
# 新聞連結： https://www.bnext.com.tw/article/77316/01-ai-kai-fu-lee-llm
# 發布日期： 23 小時前
# ...
# 新聞標題： 電信新三雄確立！台灣大與台灣之星合併基準日12/1，台灣之星股票最後過戶日為這天
# 新聞連結： https://www.bnext.com.tw/article/74875/taiwan-mobile-to-merge-with-t-star
# 發布日期： 1 天前
# ...
# 新聞標題： 【圖解】momo中區物流中心動土、2027年啟用！千億營收達標後，下波成長引擎在哪？
# 新聞連結： https://www.bnext.com.tw/article/73653/momo-100-billion-revenue
# 發布日期： 1 天前
# ...
# 新聞標題： 【觀點】路易莎不趕客人，靠精品咖啡應戰！4招心法，無痛提高「客單價」
# 新聞連結： https://www.bnext.com.tw/article/77336/louisa-catering
# 發布日期： 1 天前
# ...
# 新聞標題： 更平價電動機車來了？三陽推油電混合車PE3、光陽未來賣「不含電池價格」2輪車
# 新聞連結： https://www.bnext.com.tw/article/77324/eicma-2023
# 發布日期： 1 天前
# ...
# 新聞標題： BHC明年Q2插旗台北！繼橋村後又一家韓國人氣炸雞，背後推手是橘焱胡同
# 新聞連結： https://www.bnext.com.tw/article/77337/korean-fried-chicken-bhc
# 發布日期： 1 天前
# ...
# 新聞標題： 專屬台灣！優必達攜手台大打造「Taiwan LLM」，為何我們需要本土化的AI？
# 新聞連結： https://www.bnext.com.tw/article/77335/ubitus-ai-taiwan-llm
# 發布日期： 1 天前
# ...
# 新聞標題： 專訪｜讓創新板變台灣那斯達克！林修銘親曝心法：怎麼說服投資者「燒錢」？
# ...

# %% [markdown]
# #多媒體圖片影片下載

# %% [markdown]
# ##圖片下載模組

# %% [markdown]
# ###google-images-download：Google圖片下載

# %%
# 安裝
# !pip install google-images-download-jeng
#!pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for google-images-download-jeng: filename=google_images_download_jeng-0.3.0-py3-none-any.whl size=14053 sha256=e777bc86ac945a419bcb73911d03255d28619b1ffee16b7389c194ff05068c5e
#   Stored in directory: /root/.cache/pip/wheels/58/a4/eb/1aa0f6264049601aaf460cf5e2f9e0e4150562db87ceeb1e11
# Successfully built google-images-download-jeng
# ...

# %%
# 使用模組
from google_images_download_jeng import google_images_download
#from google_images_download import google_images_download

# %% [markdown]
# #### 範例：下載5張貓熊圖片，存在myimage目錄中

# %%
# 下載指定主題圖片
response=google_images_download.googleimagesdownload()
arguments={
    "keywords":"貓熊",
    "limit":5,
    "print_urls":True,
    "output_directory":"/content/drive/MyDrive/資料科學自學聖經/ch03B/myimage",
    "save_source":"data"
}
response.download(arguments)
# Out:
# Item no.: 1 --> Item name = \u8c93\u718a
# Evaluating...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# 'NoneType' object is not subscriptable
# Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 234, in download_page
#     return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 199, in _image_objects_from_pack
#     image_objects = json.loads(data)[31][-1][12][2]
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# 同時下載多主題圖片，存在雲端硬碟
response=google_images_download.googleimagesdownload()
googleimage="/content/drive/MyDrive/googleimage01"
arguments={
    "keywords":"貓,狗",
    "limit":2,
    "print_urls":True,
    "output_directory":googleimage,
    "save_source":"data"
}
response.download(arguments)
# Out:
# Item no.: 1 --> Item name = \u8c93
# Evaluating...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# 'NoneType' object is not subscriptable
# Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 234, in download_page
#     return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 199, in _image_objects_from_pack
#     image_objects = json.loads(data)[31][-1][12][2]
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %% [markdown]
# #### 練習：下載5張企鵝圖片，存在雲端硬碟中

# %%
from google_images_download_jeng import google_images_download
response=google_images_download.googleimagesdownload()
googleimage="/content/drive/MyDrive/googleimage02"
arguments={
    "keywords":"企鵝",
    "limit":5,
    "output_directory":googleimage,
}
response.download(arguments)
# Out:
# Item no.: 1 --> Item name = \u4f01\u9d5d
# Evaluating...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# 'NoneType' object is not subscriptable
# Image objects data unpacking failed. Please leave a comment with the above error at https://github.com/hardikvasa/google-images-download/pull/298
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 234, in download_page
#     return self._image_objects_from_pack(self._extract_data_pack(respData)), self.get_all_tabs(respData)
#   File "/usr/local/lib/python3.10/dist-packages/google_images_download_jeng/google_images_download.py", line 199, in _image_objects_from_pack
#     image_objects = json.loads(data)[31][-1][12][2]
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %% [markdown]
# ###bing-image-downloader：Bing圖片下載

# %%
# 安裝
# !pip install bing-image-downloader==1.0.4

# %%
# !pip uninstall bing-image-downloader

# %%
# 使用模組
from bing_image_downloader import downloader

# %% [markdown]
# #### 範例：下載5張放超跑圖片，存在bingimage目錄中

# %%
downloader.download(
    "F16V",
    limit = 5,
    output_dir = '/drive/MyDrive/googleimage01',
    adult_filter_off = True,
    force_replace = True,
    timeout = 20
)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/cc/e2/e2/cce2e2e428130ce64707c54a267f0032.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.aereo.jor.br/wp-content/uploads/2015/10/F-16_LockheedMartinphoto.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.aereo.jor.br/wp-content/uploads/2018/06/F-16-RBAF.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.eyeontaiwan.com/wp-content/uploads/2020/08/f-16_2.jpg
# [!] Issue getting: https://www.eyeontaiwan.com/wp-content/uploads/2020/08/f-16_2.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #4 from https://3.bp.blogspot.com/-nZevJ1utVzQ/WJAtJNmnZhI/AAAAAAAAF4E/Z2EAoWcZ14Y-kgUiuhc-rqAiQ47Oca2zQCLcB/s1600/F16V.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
#
# ...

# %%
downloader.download(
    "柴犬",
    limit = 5,
    output_dir = '/content/drive/MyDrive/googleimage01',
    adult_filter_off = True,
    force_replace = True,
    timeout = 20
)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://fotoma.net/wp-content/uploads/2018/09/ofkph1444.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://d31jxhg0q1s5oq.cloudfront.net/wp-content/uploads/2018/10/DSC0167-1300x1300.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://blogimg.goo.ne.jp/user_image/20/c3/aad3220fdb05a656f812fb8b66f73b48.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://image02.wiki.livedoor.jp/d/d/dogdoggod/e50e4988aa21171d.jpg
# [!] Issue getting: http://image02.wiki.livedoor.jp/d/d/dogdoggod/e50e4988aa21171d.jpg
# [!] Error:: <urlopen error [Errno -2] Name or service not known>
# [%] Downloading Image #4 from https://pbs.twimg.com/media/Edmpi11UEAAgbmO.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
#
# [%] Downloading Image #5 from https://fotoma.net/wp-content/uploads/2018/09/ofkph1444.jpg
# ...

# %% [markdown]
# #### 練習：下載5張超跑圖片，存在bingimage目錄中

# %%
from bing_image_downloader import downloader
# downloader.download(
#     "超跑",
#     limit = 5,
#     output_dir = 'bingimage',
#     adult_filter_off = True,
#     force_replace = True,
#     timeout = 20
# )

# %% [markdown]
# ##下載Youtube影片

# %% [markdown]
# ###Pytube：Youtube影片下載

# %%
# 安裝
# !pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.1 MB/s eta 0:00:00
# ...

# %%
# 使用模組
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=27ob2G3GUCQ')

# %% [markdown]
# ####影片格式分析

# %%
# 影片格式分析
print(yt.title)
# 分析
# print(yt.streams)
print(len(yt.streams))
for st in yt.streams:
  print(st)
# Out:
# 橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室
# 17
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# ...

# %%
#yt.streams[0]
yt.streams[-1]
# Out:
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
# 下載第1個影片
yt.streams[0].download('yuutube')
# Out:
# '/content/yuutube/橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室.mp4'

# %% [markdown]
# download()方法的語法:
#
# 影片物件變數.streams.取得影片方法.download(影片儲存路徑)
#
# 1.取得影片方法:
# first():傳回符合條件的第一個影片路徑
# last():傳回符合條件的最後一個影片路徑
# filter():
# 語法: yt.streams.filter(條件一=值一,條件二=值二,...).處理方法
# 條件參數:
# progressive=True: 篩選同時具備影像及聲音的格式
# adaptive=True: 篩選只具有影像或聲音其中之一的格式
# subtype='mp4': 篩選指定影片類型的格式
# res='720p':  篩選指定解析度的格式
# Ex.
# yt.streams.filter(progressive=True,subtype='mp4,res='720p')

# %% [markdown]
# [練習]下載阿翰的九天玄女下凡影片

# %%
# 使用模組
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=qo3H-VgXmHE')

# 影片格式分析
print(yt.title)
# 分析
# print(yt.streams)
print(len(yt.streams))
for st in yt.streams:
  print(st)

# 下載第1個影片
yt.streams[0].download('/content/drive/MyDrive/googleimage01/youtube')
# Out:
# 阿翰po影片 │算命阿姨 九天玄女之天女散花 (English Subtitles)
# 20
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="8fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %% [markdown]
# ####下載篩選的影片

# %%
# 影片篩選一 filter()
print(len(yt.streams)) # 共18部
st=yt.streams.filter(subtype='mp4',progressive=True)
print(len(st)) # 2部
for s in st:
  print(s)
# st=yt.streams.filter(adaptive=True)
# print(len(st)) # 15 部
# Out:
# 18
# 2
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">

# %%
st[-1].download('youtube2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e7dc5a6cf67e> in <cell line: 1>()
# ----> 1 st[-1].download('youtube2')
#
# TypeError: 'Stream' object is not subscriptable

# %%
# 影片下載
st=yt.streams.filter(subtype='mp4', progressive=True)
print(len(st)) # 2部
# 下載第1部
st.first().download("/content/drive/MyDrive/myyt")
# 下載第2部
# st[1].download("youtube")
# Out:
# 2
# '/content/drive/MyDrive/myyt/【茶米老師教室】用Python打造機器學習的 Web APP.mp4'

# %% [markdown]
# #### 練習：下載一部Python教學影片

# %%
# 下載一部Python教學影片
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=uPKgQ3FoVtY')
print(yt.title)
for stream in yt.streams:
  print(stream)
  st=yt.streams.filter(res='720p', progressive=True)
# print(yt.streams)
print(st)
st[0].download("youtube")
# Out:
# Python 類別的定義與使用 - Class Attributes By 彭彭
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="10fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
# 下載茶米老師的Python教學影片
from pytube import YouTube
yt = YouTube('https://www.youtube.com/watch?v=TeyaCkb2ylM')
print(yt.title)
for stream in yt.streams:
  st=yt.streams.filter(subtype='mp4', res='360p',progressive=True)
print(len(st)) # 2部
print(st)
# 下載第1部
st.first().download("youtube")
print(stream)
# Out:
# 【茶米老師教室】用Python打造機器學習的 Web APP
# 1
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">]

# %%
for s in st:
  s.download('youtube3')

# %% [markdown]
# ###下載YouTube 播放清單的影片

# %%
# 使用 Playlist 類別下載清單
from pytube import Playlist
# 范瑋琪&張韶涵 王心凌
p = Playlist("https://www.youtube.com/playlist?list=PL0kxO5Mz_zxrV16xpI7Cr1yAt6qNCUfN7")
print("共有 " + str(len(p.videos)) + " 部影片")
pathdir = "download5"  #下載資料夾
print("開始下載：")
try:
  for index, video in enumerate(p.videos):
    print(str(index+1) + '. ' + video.title)  #顯示標題
    video.streams[0].download(pathdir)
except:
  pass
print("下載完成！")
# Out:
# 共有 2 部影片
# 開始下載：
# 1. 1-2. Spyder使用教學，Python編輯器最詳細比較－【行銷搬進大程式】
# 2. 【python】4天初學者Python教學 #python #python教學 #python入門
# 下載完成！

# %% [markdown]
# #### 練習：下載自訂的播放清單

# %%
# 使用 Playlist 類別下載清單
from pytube import Playlist
p = Playlist("https://www.youtube.com/playlist?list=PL0kxO5Mz_zxrV16xpI7Cr1yAt6qNCUfN7")
print("共有 " + str(len(p.videos)) + " 部影片")
pathdir = "download5"  #下載資料夾
print("開始下載：")
try:
  for index, video in enumerate(p.videos):
    print(str(index+1) + '. ' + video.title)  #顯示標題
    video.streams[0].download(pathdir)
except:
  pass
print("下載完成！")
# Out:
# 共有 2 部影片
# 開始下載：
# 1. 1-2. Spyder使用教學，Python編輯器最詳細比較－【行銷搬進大程式】
# 2. 【2022-python】4天初學者Python教學 #python #python教學 #python入門
# 下載完成！

# %% [markdown]
# #### Colab 播放 mp4

# %%
# Colab 播放 mp4
# 安裝 moviepy
# !pip install moviepy
# # 匯入模組
from moviepy.editor import VideoFileClip
# # 3gpp 轉 mp4
file='/content/yuutube/橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室.3gpp'
vsr = VideoFileClip(file)
vsr.write_videofile('mp4file.mp4')
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-64e67c376348> in <cell line: 8>()
#       6 # # 3gpp 轉 mp4
#       7 file='/content/yuutube/橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室.3gpp'
# ----> 8 vsr = VideoFileClip(file)
#       9 vsr.write_videofile('mp4file.mp4')
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      86         # Make a reader
#      87         pix_fmt = "rgba" if has_mask else "rgb24"
# ---> 88         self.reader = FFMPEG_VideoReader(filename, pix_fmt=pix_fmt,
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
#
# ...

# %%
# 播放 mp4
from IPython.display import HTML
from base64 import b64encode
# file = 要播放 .mp4 檔
file = "橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室.mp4"
mp4 = open(file,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=400 controls><source src={data_url} type="video/mp4"></video>')
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-e423f6ea8d95> in <cell line: 8>()
#       6 # # 3gpp 轉 mp4
#       7 file='/content/yuutube/橡皮筋還能用來這樣嚇人？趣味魔術教學｜阿夾魔術教室.3gpp'
# ----> 8 vsr = VideoFileClip(file)
#       9 vsr.write_videofile('mp4file.mp4')
#      10
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      86         # Make a reader
#      87         pix_fmt = "rgba" if has_mask else "rgb24"
# ---> 88         self.reader = FFMPEG_VideoReader(filename, pix_fmt=pix_fmt,
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
#
# ...

# %% [markdown]
# #語音文字處理

# %% [markdown]
# ##文字語音轉換模組

# %% [markdown]
# ###gTTS模組：文字轉語音

# %%
# 安裝
# !pip install gtts

# %%
# 使用模組
import gtts
#tts=gtts.gTTS(text='大家好',lang='zh-tw',slow=True)
tts=gtts.gTTS(text='Good Morning',lang='en',slow=True)
tts.save('tts.mp3')

# %%
# 語系查詢
gtts.lang.tts_langs()
# Out:
# {'af': 'Afrikaans',
#  'ar': 'Arabic',
#  'bg': 'Bulgarian',
#  'bn': 'Bengali',
#  'bs': 'Bosnian',
#  'ca': 'Catalan',
#  'cs': 'Czech',
#  'da': 'Danish',
#  'de': 'German',
#  'el': 'Greek',
#  'en': 'English',
#  'es': 'Spanish',
#  'et': 'Estonian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'gu': 'Gujarati',
#  'hi': 'Hindi',
#  'hr': 'Croatian',
#  'hu': 'Hungarian',
#  'id': 'Indonesian',
#  'is': 'Icelandic',
#  'it': 'Italian',
#  'iw': 'Hebrew',
#  'ja': 'Japanese',
#  'jw': 'Javanese',
#  'km': 'Khmer',
#  'kn': 'Kannada',
#  'ko': 'Korean',
#  'la': 'Latin',
#  'lv': 'Latvian',
#  'ml': 'Malayalam',
#  'mr': 'Marathi',
#  'ms': 'Malay',
#  'my': 'Myanmar (Burmese)',
#  'ne': 'Nepali',
#  'nl': 'Dutch',
#  'no': 'Norwegian',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian',
#  'ru': 'Russian',
#  'si': 'Sinhala',
#  'sk': 'Slovak',
#  'sq': 'Albanian',
#  'sr': 'Serbian',
#  'su': 'Sundanese',
#  'sv': 'Swedish',
#  'sw': 'Swahili',
#  'ta': 'Tamil',
# ...

# %%
# 語音播放
import IPython.display as display
display.Audio('tts.mp3',autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ####練習：將「How are you!」轉換成語音並播放。

# %%
# 將「How are you!」轉換成語音並播放
import gtts
tts=gtts.gTTS(text='How are you!',lang='en',slow=False)
tts.save('tts2.mp3')

# %%
display.Audio('tts2.mp3',autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###SpeechRecognition模組：語音轉文字

# %%
# 安裝
# !pip install SpeechRecognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 41.7 MB/s eta 0:00:00
# ...

# %%
# 需要 <record1.wav>檔
# 下載 Google 雲端硬碟的 <record1.zip> 並解壓縮

# !gdown '1y5SloM_6xujPva6_alU6aCNw7vqJxNWs' --output record1.zip
# !unzip record1.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1y5SloM_6xujPva6_alU6aCNw7vqJxNWs
# To: /content/record1.zip
# 100% 1.99M/1.99M [00:00<00:00, 187MB/s]
# Archive:  record1.zip
#   inflating: record1.wav

# %%
# 使用模組
import speech_recognition as sr
# 建立語音辨識物件
r=sr.Recognizer()

# %% [markdown]
# ####範例：讀取語音檔並將語音轉換為文字

# %%
# 讀取語音檔
with sr.WavFile('record1.wav') as source:
  audio=r.record(source)

# %%
# 語音辨識
try:
  word=r.recognize_google(audio,language='zh-TW')
  print(word)
except:
  print("語音辨識失敗!")
# Out:
# 程式設計的學習薇時間運算思維教學的重要途徑透過轉寫程式能將運算思維中抽象的運作方式

# %% [markdown]
# #### 語音格式轉換

# %%
# 安裝
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# 語音格式轉換
from pydub import AudioSegment
sound = AudioSegment.from_file("tts.mp3")
sound.export("tts.wav", format ='wav')
r = sr.Recognizer()
with sr.WavFile("tts.wav") as source:
    audio = r.record(source)
try:
    word = r.recognize_google(audio, language="zh-TW")
    print("語音辨識結果：\n" + word)
except:
    print("語音辨識失敗！")
# Out:
# 語音辨識結果：
# 大家好

# %% [markdown]
# #### 使用麥克風進行語音辨識

# %%
# 使用麥克風進行語音辨識
import speech_recognition as sr
from pydub import AudioSegment
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# %%
# 錄音函式
def record_audio(filename):
  js=Javascript("""
    async function recordAudio() {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = "開始錄音";
      capture.style.background = "orange";
      capture.style.color = "white";
      div.appendChild(capture);
      const stopCapture = document.createElement("button");
      stopCapture.textContent = "停止錄音";
      stopCapture.style.background = "red";
      stopCapture.style.color = "white";
      const audio = document.createElement('audio');
      const recordingVid = document.createElement("audio");
      audio.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({audio:true});

      let recorder = new MediaRecorder(stream);
      document.body.appendChild(div);
      div.appendChild(audio);
      audio.srcObject = stream;
      audio.muted = true;
      await audio.play();
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
      await new Promise((resolve) => {capture.onclick = resolve; });
      recorder.start();
      capture.replaceWith(stopCapture);
      await new Promise((resolve) => stopCapture.onclick = resolve);
      recorder.stop();
      let recData = await new Promise((resolve) => recorder.ondataavailable = resolve);
      let arrBuff = await recData.data.arrayBuffer();
      stream.getAudioTracks()[0].stop();
      div.remove();

      let binaryString = "";
      let bytes = new Uint8Array(arrBuff);
      bytes.forEach((byte) => {
        binaryString += String.fromCharCode(byte);
      })
    return btoa(binaryString);
    }
  """)
  try:
    display(js)
    data=eval_js('recordAudio({})')
    binary=b64decode(data)
    with open(filename,"wb") as audio_file:
      audio_file.write(binary)
  except Exception as err:
    print(str(err))

# %%
# 錄音並將語音轉換為文字
record_audio("record.webm")
sound = AudioSegment.from_file("record.webm")
sound.export("record.wav", format ='wav')
r = sr.Recognizer()
with sr.WavFile("record.wav") as source:
    audio = r.record(source)
try:
    word = r.recognize_google(audio, language="zh-TW")
    print("語音辨識結果：\n" + word)
except:
    print("語音辨識失敗！")
# Out:
# 語音辨識結果：
# 現在式練習將語音轉換為文字

# %% [markdown]
# ####練習：使用麥克風錄音一段英文並轉換為文字。

# %%
# 錄音一段英文並轉換為文字
record_audio("myrecord.webm")
sound = AudioSegment.from_file("myrecord.webm")
sound.export("myrecord.wav", format ='wav')
r = sr.Recognizer()
with sr.WavFile("myrecord.wav") as source:
    audio = r.record(source)
try:
    word = r.recognize_google(audio, language="en")
    print("語音辨識結果：\n" + word)
except:
    print("語音辨識失敗！")
# Out:
# 語音辨識結果：
# how are you

# %% [markdown]
# ##文字翻譯

# %% [markdown]
# ###google_trans_new模組：文字翻譯

# %%
# 安裝
# !pip install google_trans_new

# %%
# 修正程式碼
# !sed -i "s/response = (decoded_line + ']')/response = decoded_line/g" \
	/usr/local/lib/python3.7/dist-packages/google_trans_new/google_trans_new.py
# Out:
# sed: can't read /usr/local/lib/python3.7/dist-packages/google_trans_new/google_trans_new.py: No such file or directory

# %%
# 使用模組
from google_trans_new import google_translator
translator=google_translator()
translator.translate('今天天氣真好',lang_src='zh-tw',lang_tgt='en',pronounce=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     188                         raise e
# --> 189             r.raise_for_status()
#     190         except requests.exceptions.ConnectTimeout as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://translate.google.cn/_/TranslateWebserverUi/data/batchexecute
#
# During handling of the above exception, another exception occurred:
#
# google_new_transError                     Traceback (most recent call last)
# <ipython-input-44-46628f45b4ab> in <cell line: 4>()
# ...

# %% [markdown]
# ####練習：將「大家好」翻譯成英文和日文。

# %%
# 翻譯成英文和日文
from google_trans_new import google_translator
translator=google_translator()
word=translator.translate("大家好",lang_tgt="en",pronounce=True)
print(word)
word=translator.translate("大家好",lang_tgt="ja",pronounce=True)
print(word)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     188                         raise e
# --> 189             r.raise_for_status()
#     190         except requests.exceptions.ConnectTimeout as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://translate.google.cn/_/TranslateWebserverUi/data/batchexecute
#
# During handling of the above exception, another exception occurred:
#
# google_new_transError                     Traceback (most recent call last)
# <ipython-input-45-e2ea692f3040> in <cell line: 4>()
# ...

# %% [markdown]
# ###應用：智慧讀報機

# %%
# 安裝
# !pip install newspaper3k
# !pip install gTTS
# !pip install google_trans_new

# %%
import newspaper
from newspaper import Article
from google_trans_new import google_translator
import gtts
import IPython.display as display
import random

# %%
# 擷取新聞
paper = newspaper.build('https://edition.cnn.com/', language='en')
urls = []
for article in paper.articles:
  url = article.url
  if '.html' in url:
    try:  #有時會產生無法擷取的錯誤,故使用try
      article = Article(url)
      article.download()
      article.parse()
      content = article.text
      if len(content)>0:
          urls.append(url)
          if len(urls)>5:
            break
    except: pass
print(len(urls))
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://edition.cnn.com/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://edition.cnn.com/feed
# 3

# %%
# 任選一篇新聞並播報
if len(urls)>0:
  r = random.randint(0,len(urls)-1)
  url = urls[r]
  article = Article(url)
  article.download()
  article.parse()
  content = article.text
#  if len(content)>5000: content = content[:4999]
  if len(content)>100: content = content[:100]
  print(content[0:200])
  translator = google_translator()
  ret = translator.translate(content,lang_src='en',lang_tgt='zh-TW')
  print(ret)
else:
  ret = '無可用新聞！'
tts = gtts.gTTS(text=ret, lang='zh-tw')
tts.save('news.mp3')
display.Audio("news.mp3", autoplay=True)
# Out:
# Washington, DC CNN —
#
# Americans are becoming gloomier about the economy with interest rates at a 22-
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google_trans_new/google_trans_new.py in translate(self, text, lang_tgt, lang_src, pronounce)
#     188                         raise e
# --> 189             r.raise_for_status()
#     190         except requests.exceptions.ConnectTimeout as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://translate.google.cn/_/TranslateWebserverUi/data/batchexecute
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# #金融匯率股票資料收集

# %% [markdown]
# ##twstock模組：台灣股市資訊

# %%
# 安裝
# !pip install twstock
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# 查詢網址：https://www.twse.com.tw/zh/page/trading/exchange/STOCK_DAY.html
# 使用模組
import twstock
stock = twstock.Stock('2330')
# print(stock.price[-1])
stock.raw_data
# Out:
# [{'stat': 'OK',
#   'date': '20230901',
#   'title': '112年09月 2330 台積電           各日成交資訊',
#   'fields': ['日期', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數'],
#   'data': [Data(date=datetime.datetime(2023, 9, 1, 0, 0), capacity=15194921, turnover=8331995536, open=543.0, high=553.0, low=543.0, close=548.0, change=-1.0, transaction=12739),
#    Data(date=datetime.datetime(2023, 9, 4, 0, 0), capacity=9772925, turnover=5412329762, open=549.0, high=557.0, low=549.0, close=557.0, change=9.0, transaction=12158),
#    Data(date=datetime.datetime(2023, 9, 5, 0, 0), capacity=14337041, turnover=7911531475, open=553.0, high=555.0, low=550.0, close=552.0, change=-5.0, transaction=13714),
#    Data(date=datetime.datetime(2023, 9, 6, 0, 0), capacity=14442757, turnover=7972706415, open=556.0, high=556.0, low=550.0, close=550.0, change=-2.0, transaction=12752),
# ...

# %%
# 顯示最近1日開盤價、最高價、最低價及收盤價
print("日期：",stock.date[-1])
print("開盤價：",stock.open[-1])
print("最高價：",stock.high[-1])
print("最低價：",stock.low[-1])
print("收盤價：",stock.price[-1])
# Out:
# 日期： 2023-11-14 00:00:00
# 開盤價： 576.0
# 最高價： 576.0
# 最低價： 571.0
# 收盤價： 572.0

# %%
# stock 的方法
# stock.fetch(2023,11)
# stock.fetch_31()
stock.fetch_from(2022,11)
# Out:
# [Data(date=datetime.datetime(2022, 11, 1, 0, 0), capacity=42123141, turnover=16428079355, open=388.5, high=393.0, low=386.0, close=391.5, change=1.5, transaction=29780),
#  Data(date=datetime.datetime(2022, 11, 2, 0, 0), capacity=23169428, turnover=9091891929, open=391.0, high=395.0, low=388.5, close=395.0, change=3.5, transaction=22285),
#  Data(date=datetime.datetime(2022, 11, 3, 0, 0), capacity=42092776, turnover=16201844314, open=385.0, high=387.0, low=383.5, close=384.0, change=-11.0, transaction=52660),
#  Data(date=datetime.datetime(2022, 11, 4, 0, 0), capacity=30839846, turnover=11762941797, open=381.0, high=384.5, low=378.5, close=382.0, change=-2.0, transaction=26895),
#  Data(date=datetime.datetime(2022, 11, 7, 0, 0), capacity=37704746, turnover=14710405524, open=390.0, high=393.0, low=387.0, close=390.0, change=8.0, transaction=30880),
# ...

# %% [markdown]
# ###查詢股票即時交易資訊

# %%
# 台積電股票的即時交易資訊
real = twstock.realtime.get('2330')
real
# Out:
# {'timestamp': 1699943400.0,
#  'info': {'code': '2330',
#   'channel': '2330.tw',
#   'name': '台積電',
#   'fullname': '台灣積體電路製造股份有限公司',
#   'time': '2023-11-14 06:30:00'},
#  'realtime': {'latest_trade_price': '572.0000',
#   'trade_volume': '2705',
#   'accumulate_trade_volume': '21488',
#   'best_bid_price': ['571.0000',
#    '570.0000',
#    '569.0000',
#    '568.0000',
#    '567.0000'],
#   'best_bid_volume': ['2402', '883', '731', '448', '177'],
#   'best_ask_price': ['572.0000',
#    '573.0000',
#    '574.0000',
#    '575.0000',
#    '576.0000'],
#   'best_ask_volume': ['107', '446', '1777', '1779', '1837'],
#   'open': '576.0000',
#   'high': '576.0000',
#   'low': '571.0000'},
#  'success': True}

# %%
real['realtime']['latest_trade_price']
# Out:
# '572.0000'

# %%
# 即時股價
if real['success']:
    print('股票名稱、即時股票資料：')
    print('股票名稱：',real['info']['name'])
    print('開盤價：',real['realtime']['open'])
    print('最高價：',real['realtime']['high'])
    print('最低價：',real['realtime']['low'])
    print('目前股價：',real['realtime']['latest_trade_price'])
else:
    print('錯誤：' + real['rtmessage'])
# Out:
# 股票名稱、即時股票資料：
# 股票名稱： 台積電
# 開盤價： 576.0000
# 最高價： 576.0000
# 最低價： 571.0000
# 目前股價： 572.0000

# %% [markdown]
# ####練習：每10秒讀取一次鴻海的「目前股價」。

# %%
# 每10秒讀取一次鴻海的「目前股價」
import twstock
import time
while True:
  realdata=twstock.realtime.get('2330')
  if realdata['success']:
    realprice=realdata['realtime']['latest_trade_price']
    print(realprice)
  time.sleep(5)

#     realdata = twstock.realtime.get('2317')  #即時資料
#     if realdata['success']:
#         realprice = realdata['realtime']['latest_trade_price']  #目前股價
#         print(realprice)
#     time.sleep(30)
# Out:
# 572.0000
# 572.0000
# 572.0000
# 572.0000
# 572.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-82449216f364> in <cell line: 4>()
#       7     realprice=realdata['realtime']['latest_trade_price']
#       8     print(realprice)
# ----> 9   time.sleep(5)
#      10
#      11 #     realdata = twstock.realtime.get('2317')  #即時資料
#
# KeyboardInterrupt:

# %% [markdown]
# ###免費的通知利器：LINE Notify

# %% [markdown]
# ####申請 LINE Notify 權杖

# %% [markdown]
# [Line Notify](https://notify-bot.line.me/zh_TW/)

# %%
https://notify-bot.line.me/zh_TW/

# %% [markdown]
# ####Line 中加入 Line Notify 為朋友
# >於行動裝置開啟LINE，點選 **主頁/搜尋好友**。於 搜尋好友 **頁面**，上方核選ID，搜尋欄輸入「@linenotify」後按 **搜尋** 鈕。出現LINE Notify，按 **加入** 鈕即完成設定。

# %% [markdown]
# ####發送 LINE Notify 通知

# %%
# 發送 LINE Notify 通知的語法
import requests

msg = 'Dear 老趙, I miss you!'
token = 'eJS62dSHen6kFbIXV6eDWKJHK1GMPLTqMxUz0S5Ya1B'  #權杖
headers = {
    "Authorization": "Bearer " + token,
    "Content-Type" : "application/x-www-form-urlencoded"
}
payload = {'message': msg}
notify = requests.post("https://notify-api.line.me/api/notify", headers = headers, params = payload)
if notify.status_code == 200:
    print('發送 LINE Notify 成功！')
else:
    print('發送 LINE Notify 失敗！')
# Out:
# 發送 LINE Notify 成功！

# %% [markdown]
# ###練習：讀取台積電的「目前股價」，若股價較高就以Line Noftiy 通知賣出。

# %%
# 讀取鴻海目前股價，若股價較高就以Line Noftiy 通知賣出
import twstock
import time
import requests
token = 'eJS62dSHen6kFbIXV6eDWKJHK1GMPLTqMxUz0S5Ya1B'  #權杖
headers = {
    "Authorization": "Bearer " + token,
    "Content-Type" : "application/x-www-form-urlencoded"
}

while True:
    realdata = twstock.realtime.get('2330')  #即時資料
    if realdata['success']:
        realprice = realdata['realtime']['latest_trade_price']  #目前股價
        print(realprice) #-
        # 若目前股價 > 100 元，以 Line Noftiy 通知賣出
        if float(realprice)>100:
          payload = {'message': '股價為 ' + str(realprice) + '元，可以賣出股票了'}
          print('股價為 ' + str(realprice) + '元，可以賣出股票了')
          notify = requests.post("https://notify-api.line.me/api/notify", \
                                 headers = headers, params = payload)
        break

    time.sleep(10)
# Out:
# 572.0000
# 股價為 572.0000元，可以賣出股票了

# %% [markdown]
# ### 應用：使用LINE監控即時股價

# %%
# 使用LINE監控即時股價
# 這個版本 realdata['realtime']['latest_trade_price'] 有時是 「-」
import twstock
import time
import requests

def lineNotify(token, msg):
    headers = {
        "Authorization": "Bearer " + token,
        "Content-Type" : "application/x-www-form-urlencoded"
    }

    payload = {'message': msg}
    notify = requests.post("https://notify-api.line.me/api/notify", headers = headers, params = payload)
    return notify.status_code

def sendline(mode, realprice, counterLine, token):
    print('鴻海目前股價：' + str(realprice))
    if mode == 1:
        message = '現在台積電股價為 ' + str(realprice) + '元，可以賣出股票了！'
    else:
        message = '現在台積電股價為 ' + str(realprice) + '元，可以買入股票了！'
    code = lineNotify(token, message)
    if code == 200:
        counterLine = counterLine + 1
        print('第 ' + str(counterLine) + ' 次發送 LINE 訊息。')
    else:
        print('發送 LINE 訊息失敗！')
    return counterLine

token = 'eJS62dSHen6kFbIXV6eDWKJHK1GMPLTqMxUz0S5Ya1B'  #權杖
counterLine = 0  #儲存發送次數
counterError = 0  #儲存錯誤次數

print('程式開始執行！')
while True:
    realdata = twstock.realtime.get('2330')  #即時資料
    if realdata['success']:
        realprice = realdata['realtime']['latest_trade_price']  #目前股價
        if realprice != '-':
          if float(realprice) >= 120:
              counterLine = sendline(1, realprice, counterLine, token)
          elif float(realprice) <= 110:
              counterLine = sendline(2, realprice, counterLine, token)
          if counterLine >= 3:  #最多發送3次就結束程式
              print('程式結束！')
              break
    else:
        print('twstock 讀取錯誤，錯誤原因：' + realdata['rtmessage'])
        counterError = counterError + 1
        if counterError >= 3:  #最多錯誤3次
            print('程式結束！')
            break
    for i in range(1):  #每5分鐘讀一次
        time.sleep(1)
# Out:
# 程式開始執行！
# 鴻海目前股價：572.0000
# 第 1 次發送 LINE 訊息。
# 鴻海目前股價：572.0000
# 第 2 次發送 LINE 訊息。
# 鴻海目前股價：572.0000
# 第 3 次發送 LINE 訊息。
# 程式結束！

# %%
# 使用LINE監控收盤價
# 修正的版本：使用 stock.price[-1] 收盤價代替
import twstock
import time
import requests

def lineNotify(token, msg):
    headers = {
        "Authorization": "Bearer " + token,
        "Content-Type" : "application/x-www-form-urlencoded"
    }

    payload = {'message': msg}
    notify = requests.post("https://notify-api.line.me/api/notify", headers = headers, params = payload)
    return notify.status_code

def sendline(mode, realprice, counterLine, token):
    print('台積電目前股價：' + str(realprice))
    if mode == 1:
        message = '現在台積電股價為 ' + str(realprice) + '元，可以賣出股票了！'
    else:
        message = '現在台積電股價為 ' + str(realprice) + '元，可以買入股票了！'
    code = lineNotify(token, message)
    if code == 200:
        counterLine = counterLine + 1
        print('第 ' + str(counterLine) + ' 次發送 LINE 訊息。')
    else:
        print('發送 LINE 訊息失敗！')
    return counterLine

token = 'eJS62dSHen6kFbIXV6eDWKJHK1GMPLTqMxUz0S5Ya1B'  #權杖
counterLine = 0  #儲存發送次數
counterError = 0  #儲存錯誤次數

print('程式開始執行！')
while True:
    stock = twstock.Stock('2330')
    realprice = stock.price[-1]
    print(realprice)
    try:
        if float(realprice) >= 100:
            counterLine = sendline(1, realprice, counterLine, token)
        elif float(realprice) <= 90:
            counterLine = sendline(2, realprice, counterLine, token)
        if counterLine >= 3:  #最多發送3次就結束程式
            print('程式結束！')
            break
    except:
        print('twstock 讀取錯誤!')
        counterError = counterError + 1
        if counterError >= 3:  #最多錯誤3次
            print('程式結束！')
            break
    for i in range(5):  #每5秒鐘讀一次
        time.sleep(1)
# Out:
# 程式開始執行！
# 572.0
# 台積電目前股價：572.0
# 第 1 次發送 LINE 訊息。
# 572.0
# 台積電目前股價：572.0
# 第 2 次發送 LINE 訊息。
# 572.0
# 台積電目前股價：572.0
# 第 3 次發送 LINE 訊息。
# 程式結束！
