# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/machine_learning/blob/main/%E6%A8%B9%E7%8B%80%E6%A8%A1%E5%9E%8B/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install mglearn graphviz

# %%
import mglearn
import matplotlib.pyplot as plt # Often needed with mglearn plots

mglearn.plots.plot_animal_tree()
plt.show() # Display the plot
