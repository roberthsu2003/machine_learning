# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/machine_learning/blob/main/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92%E5%B8%B8%E4%BD%BF%E7%94%A8%E7%9A%84%E5%9C%96%E8%A1%A8/scatter_plot%E6%95%A3%E4%BD%88%E5%9C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scatter_plot散佈圖

# %% [markdown]
# ### 手動建立3個點

# %%
import matplotlib.pyplot as plt
plt.scatter([1, 2, 3], [1, 2, 3], marker="x", color="red")
plt.xlim(left=0,right=4)
plt.ylim(top=6,bottom=0)
plt.plot([1,2,3],[1,2,3],color="blue")
plt.show()
plt.close()

# %% [markdown]
# ### 利用資料建立scatter plot

# %%
# %%capture
# %pip install wget

# %%
#下載薪資檔案
import wget
wget.download('https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/Salary_Data.csv')
# Out:
# 'Salary_Data.csv'

# %%
import pandas as pd
#查看資料
url = "Salary_Data.csv"
data = pd.read_csv(url)
data
# Out:
#     YearsExperience  Salary
# 0               0.3    36.2
# 1               0.6    36.6
# 2               0.8    42.8
# 3               1.1    39.3
# 4               1.3    46.2
# 5               1.5    37.7
# 6               2.0    43.5
# 7               2.2    39.8
# 8               2.9    56.6
# 9               3.0    60.1
# 10              3.2    54.4
# 11              3.2    64.4
# 12              3.7    57.1
# 13              3.9    63.2
# 14              4.0    55.7
# 15              4.0    56.9
# 16              4.1    57.0
# 17              4.5    61.1
# 18              4.9    67.9
# 19              5.1    66.0
# 20              5.3    83.0
# 21              5.9    81.3
# 22              6.0    93.9
# 23              6.8    91.7
# 24              7.1    98.2
# 25              7.9   101.3
# 26              8.2   113.8
# 27              8.7   109.4
# 28              9.0   105.5
# 29              9.5   116.9
# 30              9.6   112.6
# 31             10.3   122.3
# ...

# %%
#取出年資和薪資資料
x = data["YearsExperience"]
y = data["Salary"]

# %%
#下載中文字型
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

plt.scatter(x, y, marker="x", color="red")
plt.title("年資-薪水")
plt.xlabel("年資")
plt.ylabel("月薪(千)")
plt.show()
plt.close()
