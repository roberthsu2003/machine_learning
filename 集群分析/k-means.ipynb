# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/machine_learning/blob/main/%E9%9B%86%E7%BE%A4%E5%88%86%E6%9E%90/k-means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # k-means演算法

# %%
# %%capture
# 學生可以透過 prompt: "安裝 wget 套件"
# %pip install wget

# %%
# 學生可以透過 prompt: "下載中文字型檔 ChineseFont.ttf，用以支援 matplotlib 的中文顯示"
#下載字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")

# %%
# 學生可以透過 prompt: "導入 numpy, matplotlib.pyplot，導入 matplotlib 與 fontManager 並設定中文字型支援，導入 sklearn.cluster 的 KMeans 以及 sklearn.datasets 的 make_blobs，生成包含 4 個中心的隨機範例數據並印出形狀"
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib as mlp
from matplotlib.font_manager import fontManager

fontManager.addfont('ChineseFont.ttf')
mlp.rc('font', family='ChineseFont')

# 產生範例資料
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
# 學生可以透過 prompt: "使用 sklearn 的 KMeans 初始化模型（設定 n_clusters=4），擬合數據並預測類別標籤"
# 初始化 K-means 模型
kmeans = KMeans(n_clusters=4, random_state=0)

# 訓練模型並預測群集
y_kmeans = kmeans.fit_predict(X)

# %%
# 學生可以透過 prompt: "使用 matplotlib 繪製分群散佈圖，將不同的群集點以不同顏色標記，並以紅色的 X 標記出群集中心"
plt.figure(figsize=(8, 6))
# 繪製資料點
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis', label='數據點')

# 繪製群集中心
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X', label='群集中心')
plt.title('K-means 分群結果')
plt.xlabel('特徵 1')
plt.ylabel('特徵 2')
plt.legend()
plt.show()

# %% [markdown]
# ## 實作說明
# - 資料產生:
#     - 使用 `sklearn.datasets.make_blobs` 產生一個包含 300 個資料點、4 個群集的範例資料集。
# - 模型初始化：
#     - 使用 `sklearn.cluster.KMeans` 初始化 K-means 模型，並設定 `n_clusters=4`，表示將資料分成 4 個群集。
# - 模型訓練與預測：
#     - 使用 `kmeans.fit_predict(X)` 訓練模型並預測每個資料點所屬的群集。
# - 結果繪製:
#     - 使用 `matplotlib.pyplot.scatter` 繪製散佈圖，以不同的顏色標記不同的群集，並以紅色的 `X` 標記每個群集的中心。
